# %%
from pyNBS import data_import_tools as dit
from pyNBS import network_propagation as prop
from pyNBS import pyNBS_core as core
from pyNBS import pyNBS_single
from pyNBS import consensus_clustering as cc
from pyNBS import pyNBS_plotting as plot
from sklearn.metrics.cluster import adjusted_mutual_info_score, adjusted_rand_score
import time
import networkx as nx
import pandas as pd
import numpy as np
from IPython.display import Image

# %% [markdown]
# ## Running Parameters

# %% [markdown]
# |Param|Help|
# |:------|:------|
# |verbose|Verbosity flag for reporting on patient similarity network construction steps.|
# |sm_data_file|Path to binary mutation matrix file. May be a csv or 2-column list where each line is a sample and the gene mutated separated by a common delimiter.|
# |network_path|Path to molecular network file. File must be table where each line is a gene interaction separated by a common delimiter and the first 2 columns represent interacting proteins.|
# |mut_filetype|File structure of binary mutation data. 2 options: "matrix" (e.g. csv or tsv) or "list" (2-column list). Typically reading a "list" is faster.|
# |mut_filedelim|Delimiter used in binary mutation file. Default is tab white space.|
# |net_filedelim|Delimiter used in network file between columns. Default is tab white space.|
# |degree_preserved_shuffle|Determination of whether or not to shuffle the network edges (while preserving node degree) when loading network.|
# |node_label_shuffle|Determination of whether or not to shuffle the network node labels (while preserving network topology) when loading network.|
# |regularize_network|Determination of whether or not to calculate influence matrix regularization network for regularized NMF step.|
# |reg_net_gamma|Value of adjustment on propagation network graph laplacian to calculate influence matrix for (via Vandin 2011).|
# |k_nearest_neighbors|Number of nearest neighbors to add to the regularization network during construction.|
# |save_knn_glap|File path of where to save graph laplacian for k-nearest-neighbor network constructed from propagation network influence matrix. No path given as default, automatically saves pandas hdf file if file path given.|
# |regularization_network_graph_laplacian_file|Path to regularization network graph laplacian matrix if previously calculated. Required if 'regularize_network' is False.|
# |niter|Number of iterations to perform sub-sampling and network-regularized NMF before consensus clustering.|
# |calculate_propagation_kernel|Determination of whether or not to pre-calculate network kernel for network propagation. Highly recommended if no network kernel file is given already and niter > 10.|
# |propagation_kernel_file|Path to pre-calculated propagation kernel of network. This will save time in the propagation step.|
# |save_H|File path of where to save decomposed patient profiles. No path given as default, automatically saves csv file if file path given.|
# |consensus_cluster|Determination of whether or not to perform consensus clustering on decompositions of patient profiles.|
# |assign_clusters|Determination of whether or not to assign numerical clusters to patients based on consensus clustering of patient profiles.|
# |save_co_cluster_matrix|File path of where to save patient co-clustering matrix. No path given as default, automatically saves csv file if file path given.|
# |save_cluster_assignments|File path of where to save patient cluster assignments. No path given as default, automatically saves csv file if file path given.|
# |plot_co_cluster_map|Determination of whether or not to plot the co-clustering matrix. Requires consensus clustering and cluster assignments.|
# |plot_title|Title of co-clustering matrix map if desired.|
# |save_co_cluster_map|File path of where to save co-clustering matrix plot. No path given as default, automatically saves pdf file if file path given.|
# |save_km_plot|File path of where to save KM plot. No path given as default.|

# %%
run_pyNBS_params = {'verbose' : True,
                    ##### Path for Ovarian #####
                    
                    # Data used in this notebook is located in /data folder in the repository.
                    # To run this notebook, please modify the path to indicate your local directory.
                    # If you would like to use your own data file, 
                    # please refer to the "Load data" cell below for formatting details.
                    
                    'sm_data_file' : '/cellar/users/t1jia/pyNBS/data/OV_sm_mat_labelled.csv',
                    'network_path' : '/cellar/users/t1jia/pyNBS/data/HM90.sif',
                    
                    # Please make sure you modify file path for loading/saving to indicate your local directory
                    'mut_filetype' : 'matrix',
                    'mut_filedelim' : ',',
                    'net_filedelim' : '\t',
                    'degree_preserved_shuffle' : False,
                    'node_label_shuffle' : False,
                    
                    'regularize_network' : True,
                    'reg_net_gamma' : 0.01,
                    'k_nearest_neighbors' : 11,
                    
                    'save_knn_glap' :'/cellar/users/t1jia/Data/OV_notebook_results_1000x250/knnglap.hdf',
                    'regularization_network_graph_laplacian_file' : None,
                    'niter' : 1000, 
                    'calculate_propagation_kernel' : True,
                    
                    'propagation_kernel_file' : None,
                    'save_kernel' : '/cellar/users/t1jia/Data/OV_notebook_results_1000x250/kernel.hdf', #**
                    'save_H' : '/cellar/users/t1jia/Data/OV_notebook_results_1000x250/H/', #**
                    'consensus_cluster' : True,
                    'assign_clusters' : True,
                    
                    'save_co_cluster_matrix' : '/cellar/users/t1jia/Data/OV_notebook_results_1000x250/OV_co_cluster_matrix.csv',
                    'save_cluster_assignments' : '/cellar/users/t1jia/Data/OV_notebook_results_1000x250/OV_cluster_assignment.csv',
                    'plot_co_cluster_map' : True,
                    'plot_title' : 'Ovarian Consensus Cluster Map',
                    'save_co_cluster_map' : '/cellar/users/t1jia/Data/OV_notebook_results_1000x250/OV_co_cluster.png',
                    'save_km_plot' : '/cellar/users/t1jia/Data/OV_notebook_results_1000x250/OV_KM_plot.png'
                    }

# %% [markdown]
# ## NBS Options

# %% [markdown]
# |Option|Type|Default|Help|
# |:------|:------|:------|:------|
# |pats_subsample_p|float|0.8|Proportion of samples to sub-sample|
# |gene_subsample_p|float|0.8|Proportion of mutated genes to sub-sample|
# |min_muts|positive_int|10|Minimum number of mutations for a sample to contain after sub-sampling to be considered for further analysis|
# |prop_data|bool|True|Determination of whether or not to propagate sub-sampled binary mutation data over given molecular network
# |prop_alpha  |restricted_float|0.7|Propagation constant to use in the propagation of mutations over molecular network. Range is 0.0-1.0 exclusive. |
# |prop_symmetric_norm|bool|False|Network degree normalization method for random walk-propagation. |
# |qnorm_data  |bool  |True |Determination of whether or not to qunatile normalize mutation profiles. |
# |netNMF_k  |positive_int  |4 |Number of components to decompose patient mutation data into. Same as the number of clusters of patients to separate data into. |
# |netNMF_gamma  |positive_int  |200 |Regularization constant to scale network regularization term in netNMF. |
# |netNMF_update_gamma |bool |False |Determination of whether or not to constantly update regularization constant based on balance between reconstruction error and regularization term.|
# |netNMF_gamma_factor |positive_int |1 |Scaling factor for regularization constant updates if 'netNMF_update_gamma' is True. |
# |netNMF_niter  |positive_int  |250 |Maximum umber of multiplicative updates to perform within network-regularized NMF if result does not converge. |
# |netNMF_eps  |float  |1e-15  |Epsilon error value to adjust 0 values during multiplicative matrix updates in netNMF |
# |netNMF_err_tol  |float  |1e-4  |Minimum error tolerance for matrix reconstruction of original data for convergence. |
# |netNMF_err_delta_tol  |float  |1e-4  |Minimum error tolerance for l2 norm of difference in matrix reconstructions between iterations of netNMF for convergence. |

# %%
NBS_options = {'pats_subsample_p' : 0.8, 
               'gene_subsample_p' : 0.8, 
               'min_muts' : 10,
               'prop_data' : True, 
               'prop_alpha' : 0.7, 
               'prop_symmetric_norm' : False, 
               'qnorm_data' : True,
               'netNMF_k' : 4, 
               'netNMF_gamma' : 200, 
               'netNMF_update_gamma' : False, 
               'netNMF_gamma_factor' : 1,
               'netNMF_niter' : 250, 
               'netNMF_eps' : 1e-15, 
               'netNMF_err_tol' : 1e-4, 
               'netNMF_err_delta_tol' : 1e-8}

# %% [markdown]
# ## Load data

# %% [markdown]
# Somatic mutation data and network are __required__ to run pyNBS.
# >__Somatic mutation data__ can be of two filetypes: __matrix__ or __list__
# >>A __matrix__ is a binary csv or tsv matrix with rows represent samples/patients and columns represent genes. <br>
# Following table is an example of the somatic mutation data format:
#
# ||A1CF|A2BP1|A2M|
# |-|-|-|-|
# |TCGA-04-1638|0|0|1|
# |TCGA-23-1029|1|0|0|
# |TCGA-23-2647|0|1|0|
# |TCGA-24-1847|0|0|1|
# |TCGA-42-2589|1|0|0|
#
#
# >> A __list__ is a 2 column text file separeated by delimeter where 1st column is sample/patient, 2nd column is one gene mutated in that patient.
# The following chart is an example of a list file:
#
# |Patient ID|Gene mutated|
# |-|-|
# |TCGA-04-1638|A2M|
# |TCGA-23-1029|A1CF|
# |TCGA-23-2647|A2BP1|
# |TCGA-24-1847|A2M|
# |TCGA-42-2589|A1CF|
# >__Network file__ is a unweighted network. The default delimiter is tab, yet it can be set by user. Only the first two colcumns are read as edges for the network, all other columns will be ignored. There are also options to shuffle the network by preserving node-degree or by permuting network node labels

# %%
# Load somatic mutation data
sm_mat = dit.load_binary_mutation_data(run_pyNBS_params['sm_data_file'], filetype=run_pyNBS_params['mut_filetype'], delimiter=run_pyNBS_params['mut_filedelim'], verbose=run_pyNBS_params['verbose'])
# Load network
network = dit.load_network_file(run_pyNBS_params['network_path'], delimiter=run_pyNBS_params['net_filedelim'], degree_shuffle=run_pyNBS_params['degree_preserved_shuffle'], 
                                label_shuffle=run_pyNBS_params['node_label_shuffle'], verbose=run_pyNBS_params['verbose'])
# Out:
# Binary Mutation Matrix Loaded: /cellar/users/t1jia/pyNBS/data/OV_sm_mat_labelled.csv
# Network File Loaded: /cellar/users/t1jia/pyNBS/data/HM90.sif

# %% [markdown]
# ## knnGlap

# %% [markdown]
# Construct or load the pre-constructed KNN regularization network graph laplacian. <br> __Parameters and options:__ <br>
#
# |Parameter|Name in run_pyNBS_params|Default value|Description|
# |:-|:-|:-|:-|
# |$\gamma$|reg_net_gamma|0.01|The diagnal correction value suggested in Vandin 2011*|
# |$k_n$|k_nearest_neighbors|11|The number of nearest neighbors to construct network regularizer from|
#
# __Steps to construct knnGlap:__
# > 1. Construct network laplacian matrix
# > 2. Adjust diagonal of laplacian matrix by small gamma as seen in Vandin 2011*
# > 3. Calculate the inverse of diagonal adjusted graph laplacian to get graph influence matrix (Vandin 2011*) <br> _This method is significantly faster than the method proposed previously in NBS v0.2.0 to calculate the pseudoinverse of each network component._
# > 4. Construct KNN graph using the 11 nearest neighbors by influence score
# > 5. Save to the given path
#
# ---
# * Fabio Vandin, Eli Upfal, and Benjamin J. Raphael. Journal of Computational Biology. March 2011, 18(3): 507-522. https://doi.org/10.1089/cmb.2010.0265

# %%
# Get knnGlap
if run_pyNBS_params['regularize_network']:
    knnGlap = core.network_inf_KNN_glap(network, gamma=run_pyNBS_params['reg_net_gamma'], kn=run_pyNBS_params['k_nearest_neighbors'], verbose=run_pyNBS_params['verbose'], save_path=run_pyNBS_params['save_knn_glap'])
else:
    # Load propatagion kernel
    if run_pyNBS_params['regularization_network_graph_laplacian_file'].endswith('.hdf'):
        knnGlap = pd.read_hdf(run_pyNBS_params['regularization_network_graph_laplacian_file'])
    else:
        knnGlap = pd.read_csv(run_pyNBS_params['regularization_network_graph_laplacian_file'])
    if run_pyNBS_params['verbose']:
        print 'Pre-calculated regularization network graph laplacian loaded'
# Out:
# Graph influence matrix calculated: 16.8797490597 seconds
# /cellar/users/t1jia/anaconda2/lib/python2.7/site-packages/pandas/io/pytables.py:268: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->unicode,key->axis0] [items->None]
#
#   f(store)
# /cellar/users/t1jia/anaconda2/lib/python2.7/site-packages/pandas/io/pytables.py:268: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->unicode,key->axis1] [items->None]
#
#   f(store)
# Graph laplacian of KNN network from influence matrix calculated: 26.5549530983 seconds
# /cellar/users/t1jia/anaconda2/lib/python2.7/site-packages/pandas/io/pytables.py:268: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->unicode,key->block0_items] [items->None]
#
#   f(store)

# %% [markdown]
# ## Network propagation kernel

# %% [markdown]
# Construct or load the pre-constructed network propagation kernel.<br>
# Implementation is based on the closed form of the random walk model over networks presented by the HotNet2 paper*.<br>
#
# __Parameters and options: __
#
# |Parameters/Option|Name in run_pyNBS_params|Default|Description|Note|
# |:-|:-|:-|:-|:-|
# |$$\alpha$$|prop_alpha|0.7|Propagation constant to use in the propagation of mutations over molecular network. Range is 0.0-1.0 exclusive.|0.7 is used in Hofree paper; further tunning can be done for potentially better result|
# |symmetric_norm|prop_symmetric_norm|False|Network degree normalization method for random walk-propagation|Symetric norm is not used in the ovarian task|
#
#
# __Steps for network propagation:__
# > 1. Separate network into connected components and calculate propagation values of each sub-sample on each connected component
# > 2. Random walk propagation on all sub-graphs.<br>
# Closed form random-walk propagation for each subgraph is given by: <br>
# $$F_t = (1-\alpha)*F_o*(I-\alpha*A)^{-1}$$<br>
# Let A be the adjcency matrix, D be the diagonalized degree sum of adjacency matrix A. <br>If symmetric norm is used, then the adjacency matrix is normalized as $D^{-0.5} * A * D^{-0.5}$; Otherwise the network is normalized as $A*D^{-1}$
#
# > 3. Return propagation result as dataframe
#
# ---
# * Leiserson MDM, Vandin F, Wu H-T, et al. Pan-Cancer Network Analysis Identifies Combinations of Rare Somatic Mutations across Pathways and Protein Complexes. Nature genetics. 2015;47(2):106-114. doi:10.1038/ng.3168.

# %%
# Get network propagation kernel
if run_pyNBS_params['propagation_kernel_file'] is not None:
    # Load propagation kernel
    if run_pyNBS_params['propagation_kernel_file'].endswith('.hdf'):
        kernel = pd.read_hdf(run_pyNBS_params['propagation_kernel_file'])
    else:
        kernel = pd.read_csv(run_pyNBS_params['propagation_kernel_file'])
    if run_pyNBS_params['verbose']:
        print 'Pre-calculated network kernel loaded'
else:
    if run_pyNBS_params['calculate_propagation_kernel']:
        # Calculate propagation kernel by propagating identity matrix of network
        network_nodes = network.nodes()
        network_I = pd.DataFrame(np.identity(len(network_nodes)), index=network_nodes, columns=network_nodes)
        kernel = prop.network_propagation(network, network_I, NBS_options['prop_alpha'], verbose=True)  
        if run_pyNBS_params['verbose']:
            print 'Network kernel calculated'
    else:
        kernel = None
        if run_pyNBS_params['verbose']:
            print 'No network kernel established'
# Out:
# Performing network propagation with alpha: 0.7
# Network Propagation Complete: 49.0478899479 seconds
# Network kernel calculated

# %% [markdown]
# ## Sub-sampling and netNMF decomposition

# %% [markdown]
# __Parameters and options: __
#
# |Parameters/Option|Default|Description|
# |:-|:-|:-|
# |niter|1000|Number of iterations to perform sub-sampling and network-regularized NMF before consensus clustering|
# |pats_subsample_p|0.8|Proportion of samples to sub-sample|
# |gene_subsample_p|0.8|Proportion of mutated genes to sub-sample|
# |min_muts|10|Minimum number of mutations for a sample to contain after sub-sampling to be considered for further analysis|
# |prop_data|True|Determination of whether or not to propagate sub-sampled binary mutation data over given molecular network
# |prop_alpha  |0.7|Propagation constant to use in the propagation of mutations over molecular network. Range is 0.0-1.0 exclusive. |
# |prop_symmetric_norm|False|Network degree normalization method for random walk-propagation. |
# |qnorm_data  |True |Determination of whether or not to qunatile normalize mutation profiles. |
# |netNMF_k  |4 |Number of components to decompose patient mutation data into. Same as the number of clusters of patients to separate data into. |
# |netNMF_gamma  |200 |Regularization constant to scale network regularization term in netNMF. |
# |netNMF_update_gamma |False |Determination of whether or not to constantly update regularization constant based on balance between reconstruction error and regularization term.|
# |netNMF_gamma_factor |1 |Scaling factor for regularization constant updates if 'netNMF_update_gamma' is True. |
# |netNMF_niter  |250 |Maximum umber of multiplicative updates to perform within network-regularized NMF if result does not converge. |
# |netNMF_eps  |1e-15  |Epsilon error value to adjust 0 values during multiplicative matrix updates in netNMF |
# |netNMF_err_tol  |1e-4  |Minimum error tolerance for matrix reconstruction of original data for convergence. |
# |netNMF_err_delta_tol  |1e-4  |Minimum error tolerance for l2 norm of difference in matrix reconstructions between iterations of netNMF for convergence. |
#
# __Steps for Sub-sampling and netNMF decomposition__
# > __Subsampling__
#   1. Sub-sample binary somatic mutation profile based on _pats_subsample_p_ and _gene_subsample_p_;
#   2. Filter min mutation based on _min_muts_;
#   3. Filter columns by network nodes if a network is provided
#
# > __Propagate data (Optional but recommanded)__
#   1. If no kernel is provided, use closed form of the random walk model over full network by subgraphs (HotNet2)
#   2. If a pre-calculated kernel is provided, propagate binary mutation matrix over network by subgraph. Pre-calcuated kernel saves a significant amount of time for many runs of NBS
#
# > __Quantile normalization (Optional)__
#   1. Sort each patient by gene propagation value
#   2. Rank averages for each gene across samples
#   3. Assign ranked averages to ranks of each gene for each sample
#
# > __netNMF decomposition__
#   1. In each iternation, update W and H with network constrains
#   2. Track reconstruction errors and residuals

# %%
Hlist = []
time_list = []
for i in range(run_pyNBS_params['niter']):
    netNMF_time = time.time()
    Hlist.append(pyNBS_single.NBS_single(sm_mat, NBS_options, propNet=network, propNet_kernel=kernel, regNet_glap=knnGlap, verbose=False, save_path=run_pyNBS_params['save_H']+repr(i+1)))
    if run_pyNBS_params['verbose']:
        t = time.time()-netNMF_time
        time_list.append(t)
        print 'NBS iteration:', i+1, 'complete:', t, 'seconds'
np.savetxt('/cellar/users/t1jia/Data/OV_notebook_results_1000x250/NBS_iteration_time.csv',time_list)
# Out:
# NBS iteration: 1 complete: 47.8778209686 seconds
# NBS iteration: 2 complete: 46.9986858368 seconds
# NBS iteration: 3 complete: 47.0329289436 seconds
# NBS iteration: 4 complete: 46.9112420082 seconds
# NBS iteration: 5 complete: 46.6788511276 seconds
# NBS iteration: 6 complete: 46.6789150238 seconds
# NBS iteration: 7 complete: 46.4004878998 seconds
# NBS iteration: 8 complete: 47.3567919731 seconds
# NBS iteration: 9 complete: 47.8050639629 seconds
# NBS iteration: 10 complete: 47.4511749744 seconds
# NBS iteration: 11 complete: 48.4303228855 seconds
# NBS iteration: 12 complete: 46.7876849174 seconds
# NBS iteration: 13 complete: 49.291476965 seconds
# NBS iteration: 14 complete: 47.5430631638 seconds
# NBS iteration: 15 complete: 47.8464281559 seconds
# NBS iteration: 16 complete: 47.9694268703 seconds
# NBS iteration: 17 complete: 48.4831159115 seconds
# NBS iteration: 18 complete: 48.2247509956 seconds
# NBS iteration: 19 complete: 48.5060770512 seconds
# NBS iteration: 20 complete: 48.9653120041 seconds
# NBS iteration: 21 complete: 48.2316811085 seconds
# NBS iteration: 22 complete: 49.1040151119 seconds
# NBS iteration: 23 complete: 48.6796779633 seconds
# NBS iteration: 24 complete: 49.1955251694 seconds
# NBS iteration: 25 complete: 49.8425829411 seconds
# NBS iteration: 26 complete: 49.7822780609 seconds
# NBS iteration: 27 complete: 49.4286501408 seconds
# NBS iteration: 28 complete: 49.7607278824 seconds
# NBS iteration: 29 complete: 50.0761990547 seconds
# NBS iteration: 30 complete: 50.758286953 seconds
# NBS iteration: 31 complete: 51.0426969528 seconds
# NBS iteration: 32 complete: 51.2787280083 seconds
# NBS iteration: 33 complete: 51.3567340374 seconds
# NBS iteration: 34 complete: 51.3947341442 seconds
# NBS iteration: 35 complete: 52.0127851963 seconds
# NBS iteration: 36 complete: 51.5767350197 seconds
# NBS iteration: 37 complete: 52.3711287975 seconds
# NBS iteration: 38 complete: 47.4475340843 seconds
# NBS iteration: 39 complete: 46.6095819473 seconds
# NBS iteration: 40 complete: 47.294891119 seconds
# NBS iteration: 41 complete: 47.513725996 seconds
# NBS iteration: 42 complete: 46.5917899609 seconds
# NBS iteration: 43 complete: 46.6037890911 seconds
# NBS iteration: 44 complete: 45.9117209911 seconds
# NBS iteration: 45 complete: 47.9328119755 seconds
# NBS iteration: 46 complete: 46.7873020172 seconds
# NBS iteration: 47 complete: 46.5652701855 seconds
# NBS iteration: 48 complete: 47.6182851791 seconds
# NBS iteration: 49 complete: 46.9640500546 seconds
# NBS iteration: 50 complete: 46.9929702282 seconds
# NBS iteration: 51 complete: 46.7793078423 seconds
# NBS iteration: 52 complete: 46.7717330456 seconds
# NBS iteration: 53 complete: 47.2388238907 seconds
# NBS iteration: 54 complete: 46.6920490265 seconds
# NBS iteration: 55 complete: 47.6793429852 seconds
# NBS iteration: 56 complete: 47.6040341854 seconds
# NBS iteration: 57 complete: 47.5243020058 seconds
# NBS iteration: 58 complete: 47.6600079536 seconds
# NBS iteration: 59 complete: 48.2376589775 seconds
# NBS iteration: 60 complete: 48.4414401054 seconds
# NBS iteration: 61 complete: 47.7342560291 seconds
# NBS iteration: 62 complete: 47.7044689655 seconds
# NBS iteration: 63 complete: 47.9040229321 seconds
# NBS iteration: 64 complete: 48.5593290329 seconds
# NBS iteration: 65 complete: 47.4545090199 seconds
# NBS iteration: 66 complete: 48.4517309666 seconds
# NBS iteration: 67 complete: 48.2284038067 seconds
# NBS iteration: 68 complete: 48.8535289764 seconds
# NBS iteration: 69 complete: 48.5501489639 seconds
# NBS iteration: 70 complete: 48.3484129906 seconds
# NBS iteration: 71 complete: 48.6673429012 seconds
# NBS iteration: 72 complete: 48.977861166 seconds
# NBS iteration: 73 complete: 48.7388148308 seconds
# NBS iteration: 74 complete: 48.865031004 seconds
# NBS iteration: 75 complete: 48.3859829903 seconds
# NBS iteration: 76 complete: 49.938999176 seconds
# NBS iteration: 77 complete: 48.7098591328 seconds
# NBS iteration: 78 complete: 49.3089129925 seconds
# NBS iteration: 79 complete: 49.0593459606 seconds
# NBS iteration: 80 complete: 49.4271998405 seconds
# NBS iteration: 81 complete: 49.6843719482 seconds
# NBS iteration: 82 complete: 49.9815311432 seconds
# NBS iteration: 83 complete: 49.6162838936 seconds
# NBS iteration: 84 complete: 50.0024518967 seconds
# NBS iteration: 85 complete: 51.1453380585 seconds
# NBS iteration: 86 complete: 49.6064949036 seconds
# NBS iteration: 87 complete: 50.0733242035 seconds
# NBS iteration: 88 complete: 50.5821118355 seconds
# NBS iteration: 89 complete: 50.805218935 seconds
# NBS iteration: 90 complete: 50.5549738407 seconds
# NBS iteration: 91 complete: 50.8232831955 seconds
# NBS iteration: 92 complete: 51.5690860748 seconds
# NBS iteration: 93 complete: 50.5854990482 seconds
# NBS iteration: 94 complete: 51.0415239334 seconds
# NBS iteration: 95 complete: 50.7511370182 seconds
# NBS iteration: 96 complete: 51.0098030567 seconds
# NBS iteration: 97 complete: 51.160392046 seconds
# NBS iteration: 98 complete: 51.6619319916 seconds
# NBS iteration: 99 complete: 50.9150190353 seconds
# NBS iteration: 100 complete: 51.1465308666 seconds
# NBS iteration: 101 complete: 48.1907329559 seconds
# NBS iteration: 102 complete: 47.5632019043 seconds
# NBS iteration: 103 complete: 46.9800560474 seconds
# NBS iteration: 104 complete: 46.6155431271 seconds
# NBS iteration: 105 complete: 47.0730938911 seconds
# NBS iteration: 106 complete: 46.8379030228 seconds
# NBS iteration: 107 complete: 46.869961977 seconds
# NBS iteration: 108 complete: 46.3357210159 seconds
# NBS iteration: 109 complete: 46.5407509804 seconds
# NBS iteration: 110 complete: 47.1283459663 seconds
# NBS iteration: 111 complete: 46.8615040779 seconds
# NBS iteration: 112 complete: 47.378401041 seconds
# NBS iteration: 113 complete: 47.3002347946 seconds
# NBS iteration: 114 complete: 46.6299500465 seconds
# NBS iteration: 115 complete: 46.1879620552 seconds
# NBS iteration: 116 complete: 46.8455910683 seconds
# NBS iteration: 117 complete: 47.577573061 seconds
# NBS iteration: 118 complete: 47.8461949825 seconds
# NBS iteration: 119 complete: 47.5117819309 seconds
# NBS iteration: 120 complete: 47.8405780792 seconds
# NBS iteration: 121 complete: 47.614675045 seconds
# NBS iteration: 122 complete: 49.1418840885 seconds
# NBS iteration: 123 complete: 47.877974987 seconds
# NBS iteration: 124 complete: 47.2558219433 seconds
# NBS iteration: 125 complete: 47.963050127 seconds
# NBS iteration: 126 complete: 47.1993238926 seconds
# NBS iteration: 127 complete: 47.9125800133 seconds
# NBS iteration: 128 complete: 47.9222939014 seconds
# NBS iteration: 129 complete: 48.4272840023 seconds
# NBS iteration: 130 complete: 48.6848380566 seconds
# NBS iteration: 131 complete: 49.0045411587 seconds
# NBS iteration: 132 complete: 49.1704289913 seconds
# NBS iteration: 133 complete: 49.0214691162 seconds
# NBS iteration: 134 complete: 49.717400074 seconds
# NBS iteration: 135 complete: 49.4155409336 seconds
# NBS iteration: 136 complete: 49.0736880302 seconds
# NBS iteration: 137 complete: 49.1260540485 seconds
# NBS iteration: 138 complete: 49.4688990116 seconds
# NBS iteration: 139 complete: 49.6076738834 seconds
# NBS iteration: 140 complete: 49.6668100357 seconds
# NBS iteration: 141 complete: 49.3279769421 seconds
# NBS iteration: 142 complete: 48.9090600014 seconds
# NBS iteration: 143 complete: 49.3347029686 seconds
# NBS iteration: 144 complete: 49.4935128689 seconds
# NBS iteration: 145 complete: 49.3961598873 seconds
# NBS iteration: 146 complete: 49.5381212234 seconds
# NBS iteration: 147 complete: 50.1872599125 seconds
# NBS iteration: 148 complete: 49.5059900284 seconds
# NBS iteration: 149 complete: 50.1400561333 seconds
# NBS iteration: 150 complete: 49.8882329464 seconds
# NBS iteration: 151 complete: 50.2625751495 seconds
# NBS iteration: 152 complete: 47.2401981354 seconds
# NBS iteration: 153 complete: 47.0818440914 seconds
# NBS iteration: 154 complete: 47.0118179321 seconds
# NBS iteration: 155 complete: 47.0183420181 seconds
# NBS iteration: 156 complete: 45.5091900826 seconds
# NBS iteration: 157 complete: 46.5719618797 seconds
# NBS iteration: 158 complete: 47.0352389812 seconds
# NBS iteration: 159 complete: 48.1462738514 seconds
# NBS iteration: 160 complete: 46.4183750153 seconds
# NBS iteration: 161 complete: 46.9145619869 seconds
# NBS iteration: 162 complete: 47.4904870987 seconds
# NBS iteration: 163 complete: 46.8449549675 seconds
# NBS iteration: 164 complete: 46.6629209518 seconds
# NBS iteration: 165 complete: 46.8754208088 seconds
# NBS iteration: 166 complete: 46.4543399811 seconds
# NBS iteration: 167 complete: 47.0339539051 seconds
# NBS iteration: 168 complete: 47.9758429527 seconds
# NBS iteration: 169 complete: 46.4596319199 seconds
# NBS iteration: 170 complete: 46.6563332081 seconds
# NBS iteration: 171 complete: 46.9345400333 seconds
# NBS iteration: 172 complete: 46.6022040844 seconds
# NBS iteration: 173 complete: 47.370775938 seconds
# NBS iteration: 174 complete: 46.6248748302 seconds
# NBS iteration: 175 complete: 46.6579101086 seconds
# NBS iteration: 176 complete: 46.9760868549 seconds
# NBS iteration: 177 complete: 46.5624129772 seconds
# NBS iteration: 178 complete: 46.6525330544 seconds
# NBS iteration: 179 complete: 46.5405831337 seconds
# NBS iteration: 180 complete: 47.2326800823 seconds
# NBS iteration: 181 complete: 46.8711020947 seconds
# NBS iteration: 182 complete: 46.9672939777 seconds
# NBS iteration: 183 complete: 47.13935709 seconds
# NBS iteration: 184 complete: 45.6318590641 seconds
# NBS iteration: 185 complete: 47.3274209499 seconds
# NBS iteration: 186 complete: 46.9608418941 seconds
# NBS iteration: 187 complete: 46.4610528946 seconds
# NBS iteration: 188 complete: 46.7195808887 seconds
# NBS iteration: 189 complete: 47.2806220055 seconds
# NBS iteration: 190 complete: 47.1869139671 seconds
# NBS iteration: 191 complete: 47.1960699558 seconds
# NBS iteration: 192 complete: 47.0865418911 seconds
# NBS iteration: 193 complete: 46.8227069378 seconds
# NBS iteration: 194 complete: 46.5719280243 seconds
# NBS iteration: 195 complete: 47.3792879581 seconds
# NBS iteration: 196 complete: 47.1773569584 seconds
# NBS iteration: 197 complete: 48.8788340092 seconds
# NBS iteration: 198 complete: 47.0127270222 seconds
# NBS iteration: 199 complete: 47.4715340137 seconds
# NBS iteration: 200 complete: 47.4255299568 seconds
# NBS iteration: 201 complete: 47.3626139164 seconds
# NBS iteration: 202 complete: 47.3730359077 seconds
# NBS iteration: 203 complete: 47.4258008003 seconds
# NBS iteration: 204 complete: 47.5179619789 seconds
# NBS iteration: 205 complete: 47.8401548862 seconds
# NBS iteration: 206 complete: 47.2915389538 seconds
# NBS iteration: 207 complete: 47.8827109337 seconds
# NBS iteration: 208 complete: 47.4232120514 seconds
# NBS iteration: 209 complete: 47.6422028542 seconds
# NBS iteration: 210 complete: 48.1509890556 seconds
# NBS iteration: 211 complete: 47.7348029613 seconds
# NBS iteration: 212 complete: 48.0184600353 seconds
# NBS iteration: 213 complete: 48.0734388828 seconds
# NBS iteration: 214 complete: 48.5388259888 seconds
# NBS iteration: 215 complete: 48.4650819302 seconds
# NBS iteration: 216 complete: 48.6975669861 seconds
# NBS iteration: 217 complete: 48.4698200226 seconds
# NBS iteration: 218 complete: 48.7061359882 seconds
# NBS iteration: 219 complete: 48.173910141 seconds
# NBS iteration: 220 complete: 49.0799651146 seconds
# NBS iteration: 221 complete: 48.7336080074 seconds
# NBS iteration: 222 complete: 48.687308073 seconds
# NBS iteration: 223 complete: 48.6973979473 seconds
# NBS iteration: 224 complete: 49.0445418358 seconds
# NBS iteration: 225 complete: 49.0557370186 seconds
# NBS iteration: 226 complete: 48.8836672306 seconds
# NBS iteration: 227 complete: 48.9629728794 seconds
# NBS iteration: 228 complete: 49.0246651173 seconds
# NBS iteration: 229 complete: 49.2197399139 seconds
# NBS iteration: 230 complete: 49.1938688755 seconds
# NBS iteration: 231 complete: 49.0680229664 seconds
# NBS iteration: 232 complete: 50.3324398994 seconds
# NBS iteration: 233 complete: 49.5415318012 seconds
# NBS iteration: 234 complete: 50.9357419014 seconds
# NBS iteration: 235 complete: 49.5632410049 seconds
# NBS iteration: 236 complete: 51.0021147728 seconds
# NBS iteration: 237 complete: 49.2986388206 seconds
# NBS iteration: 238 complete: 49.3925709724 seconds
# NBS iteration: 239 complete: 49.5878560543 seconds
# NBS iteration: 240 complete: 49.7931101322 seconds
# NBS iteration: 241 complete: 49.2200140953 seconds
# NBS iteration: 242 complete: 50.0908927917 seconds
# NBS iteration: 243 complete: 50.0591609478 seconds
# NBS iteration: 244 complete: 49.4868600368 seconds
# NBS iteration: 245 complete: 50.0939879417 seconds
# NBS iteration: 246 complete: 50.0466048717 seconds
# NBS iteration: 247 complete: 49.7399840355 seconds
# NBS iteration: 248 complete: 49.86145401 seconds
# NBS iteration: 249 complete: 50.5681290627 seconds
# NBS iteration: 250 complete: 50.3973419666 seconds
# NBS iteration: 251 complete: 51.1364779472 seconds
# NBS iteration: 252 complete: 51.2525868416 seconds
# NBS iteration: 253 complete: 50.8166389465 seconds
# NBS iteration: 254 complete: 51.3341419697 seconds
# NBS iteration: 255 complete: 50.2983310223 seconds
# NBS iteration: 256 complete: 48.5623991489 seconds
# NBS iteration: 257 complete: 48.9099781513 seconds
# NBS iteration: 258 complete: 48.9494259357 seconds
# NBS iteration: 259 complete: 48.839936018 seconds
# NBS iteration: 260 complete: 48.5797870159 seconds
# NBS iteration: 261 complete: 49.3290660381 seconds
# NBS iteration: 262 complete: 49.1032018661 seconds
# NBS iteration: 263 complete: 49.923235178 seconds
# NBS iteration: 264 complete: 49.5553979874 seconds
# NBS iteration: 265 complete: 49.9829502106 seconds
# NBS iteration: 266 complete: 50.2109959126 seconds
# NBS iteration: 267 complete: 49.4485712051 seconds
# NBS iteration: 268 complete: 49.2516188622 seconds
# NBS iteration: 269 complete: 50.2245810032 seconds
# NBS iteration: 270 complete: 51.2068879604 seconds
# NBS iteration: 271 complete: 51.2874310017 seconds
# NBS iteration: 272 complete: 51.8078389168 seconds
# NBS iteration: 273 complete: 51.4405119419 seconds
# NBS iteration: 274 complete: 51.1223278046 seconds
# NBS iteration: 275 complete: 51.2941710949 seconds
# NBS iteration: 276 complete: 51.6749360561 seconds
# NBS iteration: 277 complete: 52.6008691788 seconds
# NBS iteration: 278 complete: 52.5511040688 seconds
# NBS iteration: 279 complete: 53.5355629921 seconds
# NBS iteration: 280 complete: 53.2282280922 seconds
# NBS iteration: 281 complete: 54.0640850067 seconds
# NBS iteration: 282 complete: 48.4480850697 seconds
# NBS iteration: 283 complete: 46.0838770866 seconds
# NBS iteration: 284 complete: 46.6847321987 seconds
# NBS iteration: 285 complete: 46.5627090931 seconds
# NBS iteration: 286 complete: 46.4844369888 seconds
# NBS iteration: 287 complete: 46.7781751156 seconds
# NBS iteration: 288 complete: 47.5971200466 seconds
# NBS iteration: 289 complete: 47.1888930798 seconds
# NBS iteration: 290 complete: 47.1140708923 seconds
# NBS iteration: 291 complete: 48.2004189491 seconds
# NBS iteration: 292 complete: 47.4680280685 seconds
# NBS iteration: 293 complete: 47.730812788 seconds
# NBS iteration: 294 complete: 47.9623990059 seconds
# NBS iteration: 295 complete: 48.3888092041 seconds
# NBS iteration: 296 complete: 48.5069050789 seconds
# NBS iteration: 297 complete: 49.0797531605 seconds
# NBS iteration: 298 complete: 48.8468849659 seconds
# NBS iteration: 299 complete: 48.6803321838 seconds
# NBS iteration: 300 complete: 49.5444209576 seconds
# NBS iteration: 301 complete: 48.7990069389 seconds
# NBS iteration: 302 complete: 49.6978051662 seconds
# NBS iteration: 303 complete: 49.1956009865 seconds
# NBS iteration: 304 complete: 49.4104640484 seconds
# NBS iteration: 305 complete: 48.8314619064 seconds
# NBS iteration: 306 complete: 49.3951880932 seconds
# NBS iteration: 307 complete: 52.1686849594 seconds
# NBS iteration: 308 complete: 49.8251430988 seconds
# NBS iteration: 309 complete: 50.3113489151 seconds
# NBS iteration: 310 complete: 49.6288330555 seconds
# NBS iteration: 311 complete: 49.8731169701 seconds
# NBS iteration: 312 complete: 49.4280879498 seconds
# NBS iteration: 313 complete: 47.5808019638 seconds
# NBS iteration: 314 complete: 46.6401019096 seconds
# NBS iteration: 315 complete: 47.011149168 seconds
# NBS iteration: 316 complete: 46.5652248859 seconds
# NBS iteration: 317 complete: 46.8090159893 seconds
# NBS iteration: 318 complete: 47.1040821075 seconds
# NBS iteration: 319 complete: 47.0457568169 seconds
# NBS iteration: 320 complete: 47.406293869 seconds
# NBS iteration: 321 complete: 47.9246890545 seconds
# NBS iteration: 322 complete: 47.7227079868 seconds
# NBS iteration: 323 complete: 47.6179330349 seconds
# NBS iteration: 324 complete: 48.3093838692 seconds
# NBS iteration: 325 complete: 48.05864501 seconds
# NBS iteration: 326 complete: 49.1354291439 seconds
# NBS iteration: 327 complete: 48.7602550983 seconds
# NBS iteration: 328 complete: 49.1444139481 seconds
# NBS iteration: 329 complete: 48.9301059246 seconds
# NBS iteration: 330 complete: 48.9702150822 seconds
# NBS iteration: 331 complete: 48.8908240795 seconds
# NBS iteration: 332 complete: 49.0807180405 seconds
# NBS iteration: 333 complete: 49.5564827919 seconds
# NBS iteration: 334 complete: 49.9616479874 seconds
# NBS iteration: 335 complete: 50.0482091904 seconds
# NBS iteration: 336 complete: 50.2653689384 seconds
# NBS iteration: 337 complete: 49.6554179192 seconds
# NBS iteration: 338 complete: 49.7575519085 seconds
# NBS iteration: 339 complete: 50.1380519867 seconds
# NBS iteration: 340 complete: 50.2904040813 seconds
# NBS iteration: 341 complete: 50.5144388676 seconds
# NBS iteration: 342 complete: 51.2436859608 seconds
# NBS iteration: 343 complete: 51.091105938 seconds
# NBS iteration: 344 complete: 51.7104589939 seconds
# NBS iteration: 345 complete: 51.5289609432 seconds
# NBS iteration: 346 complete: 51.3163940907 seconds
# NBS iteration: 347 complete: 51.5579748154 seconds
# NBS iteration: 348 complete: 52.5652651787 seconds
# NBS iteration: 349 complete: 52.1124479771 seconds
# NBS iteration: 350 complete: 52.6224009991 seconds
# NBS iteration: 351 complete: 52.1352550983 seconds
# NBS iteration: 352 complete: 52.2142899036 seconds
# NBS iteration: 353 complete: 52.1475908756 seconds
# NBS iteration: 354 complete: 50.1876769066 seconds
# NBS iteration: 355 complete: 47.4838578701 seconds
# NBS iteration: 356 complete: 47.3154599667 seconds
# NBS iteration: 357 complete: 47.376336813 seconds
# NBS iteration: 358 complete: 48.3541660309 seconds
# NBS iteration: 359 complete: 47.2106590271 seconds
# NBS iteration: 360 complete: 47.2791311741 seconds
# NBS iteration: 361 complete: 46.8764441013 seconds
# NBS iteration: 362 complete: 47.4923429489 seconds
# NBS iteration: 363 complete: 47.6091079712 seconds
# NBS iteration: 364 complete: 47.6626229286 seconds
# NBS iteration: 365 complete: 47.9502999783 seconds
# NBS iteration: 366 complete: 47.837045908 seconds
# NBS iteration: 367 complete: 47.5919249058 seconds
# NBS iteration: 368 complete: 47.6260101795 seconds
# NBS iteration: 369 complete: 47.2786400318 seconds
# NBS iteration: 370 complete: 46.7268810272 seconds
# NBS iteration: 371 complete: 47.9546470642 seconds
# NBS iteration: 372 complete: 47.7893130779 seconds
# NBS iteration: 373 complete: 47.5284879208 seconds
# NBS iteration: 374 complete: 47.7553141117 seconds
# NBS iteration: 375 complete: 48.0763070583 seconds
# NBS iteration: 376 complete: 47.8221821785 seconds
# NBS iteration: 377 complete: 48.0015559196 seconds
# NBS iteration: 378 complete: 48.360350132 seconds
# NBS iteration: 379 complete: 48.3125870228 seconds
# NBS iteration: 380 complete: 49.658908844 seconds
# NBS iteration: 381 complete: 48.6701688766 seconds
# NBS iteration: 382 complete: 48.8853280544 seconds
# NBS iteration: 383 complete: 47.5205860138 seconds
# NBS iteration: 384 complete: 48.5870890617 seconds
# NBS iteration: 385 complete: 48.6235370636 seconds
# NBS iteration: 386 complete: 48.8210949898 seconds
# NBS iteration: 387 complete: 49.4307248592 seconds
# NBS iteration: 388 complete: 48.21976614 seconds
# NBS iteration: 389 complete: 49.2085809708 seconds
# NBS iteration: 390 complete: 48.5967898369 seconds
# NBS iteration: 391 complete: 49.184525013 seconds
# NBS iteration: 392 complete: 48.8612031937 seconds
# NBS iteration: 393 complete: 48.7372250557 seconds
# NBS iteration: 394 complete: 49.5401530266 seconds
# NBS iteration: 395 complete: 49.4425368309 seconds
# NBS iteration: 396 complete: 49.5706880093 seconds
# NBS iteration: 397 complete: 50.0249018669 seconds
# NBS iteration: 398 complete: 49.8751339912 seconds
# NBS iteration: 399 complete: 51.1529741287 seconds
# NBS iteration: 400 complete: 50.7421050072 seconds
# NBS iteration: 401 complete: 50.8109190464 seconds
# NBS iteration: 402 complete: 51.631759882 seconds
# NBS iteration: 403 complete: 51.6891109943 seconds
# NBS iteration: 404 complete: 52.8020620346 seconds
# NBS iteration: 405 complete: 52.5457501411 seconds
# NBS iteration: 406 complete: 53.3955330849 seconds
# NBS iteration: 407 complete: 54.2863838673 seconds
# NBS iteration: 408 complete: 55.6883859634 seconds
# NBS iteration: 409 complete: 55.9885878563 seconds
# NBS iteration: 410 complete: 55.6548280716 seconds
# NBS iteration: 411 complete: 56.1234669685 seconds
# NBS iteration: 412 complete: 56.4167788029 seconds
# NBS iteration: 413 complete: 56.3359532356 seconds
# NBS iteration: 414 complete: 48.0502820015 seconds
# NBS iteration: 415 complete: 47.4879910946 seconds
# NBS iteration: 416 complete: 48.6565830708 seconds
# NBS iteration: 417 complete: 47.5211701393 seconds
# NBS iteration: 418 complete: 47.3571228981 seconds
# NBS iteration: 419 complete: 47.2022550106 seconds
# NBS iteration: 420 complete: 48.0042698383 seconds
# NBS iteration: 421 complete: 47.8171138763 seconds
# NBS iteration: 422 complete: 48.6327178478 seconds
# NBS iteration: 423 complete: 48.7318408489 seconds
# NBS iteration: 424 complete: 49.1545259953 seconds
# NBS iteration: 425 complete: 48.6043698788 seconds
# NBS iteration: 426 complete: 49.3794891834 seconds
# NBS iteration: 427 complete: 49.557215929 seconds
# NBS iteration: 428 complete: 49.2669150829 seconds
# NBS iteration: 429 complete: 49.6923902035 seconds
# NBS iteration: 430 complete: 50.109577179 seconds
# NBS iteration: 431 complete: 50.4575800896 seconds
# NBS iteration: 432 complete: 50.3376851082 seconds
# NBS iteration: 433 complete: 50.7957110405 seconds
# NBS iteration: 434 complete: 50.3691840172 seconds
# NBS iteration: 435 complete: 50.8833079338 seconds
# NBS iteration: 436 complete: 51.1945819855 seconds
# NBS iteration: 437 complete: 51.7726130486 seconds
# NBS iteration: 438 complete: 50.2524719238 seconds
# NBS iteration: 439 complete: 51.0883090496 seconds
# NBS iteration: 440 complete: 51.1417841911 seconds
# NBS iteration: 441 complete: 51.4147610664 seconds
# NBS iteration: 442 complete: 50.6682419777 seconds
# NBS iteration: 443 complete: 51.3980300426 seconds
# NBS iteration: 444 complete: 51.0869040489 seconds
# NBS iteration: 445 complete: 51.4516670704 seconds
# NBS iteration: 446 complete: 51.4526758194 seconds
# NBS iteration: 447 complete: 52.3037641048 seconds
# NBS iteration: 448 complete: 52.0111289024 seconds
# NBS iteration: 449 complete: 52.2909510136 seconds
# NBS iteration: 450 complete: 52.646378994 seconds
# NBS iteration: 451 complete: 53.0128879547 seconds
# NBS iteration: 452 complete: 53.3177540302 seconds
# NBS iteration: 453 complete: 53.922219038 seconds
# NBS iteration: 454 complete: 54.3780720234 seconds
# NBS iteration: 455 complete: 54.5877830982 seconds
# NBS iteration: 456 complete: 54.5002560616 seconds
# NBS iteration: 457 complete: 55.4148750305 seconds
# NBS iteration: 458 complete: 55.7294631004 seconds
# NBS iteration: 459 complete: 55.8161289692 seconds
# NBS iteration: 460 complete: 56.5223989487 seconds
# NBS iteration: 461 complete: 55.6594910622 seconds
# NBS iteration: 462 complete: 56.915323019 seconds
# NBS iteration: 463 complete: 53.3611650467 seconds
# NBS iteration: 464 complete: 49.6357519627 seconds
# NBS iteration: 465 complete: 48.3872010708 seconds
# NBS iteration: 466 complete: 49.052850008 seconds
# NBS iteration: 467 complete: 48.574821949 seconds
# NBS iteration: 468 complete: 48.9307529926 seconds
# NBS iteration: 469 complete: 49.0475668907 seconds
# NBS iteration: 470 complete: 48.8373689651 seconds
# NBS iteration: 471 complete: 49.9198019505 seconds
# NBS iteration: 472 complete: 49.7164731026 seconds
# NBS iteration: 473 complete: 50.1741039753 seconds
# NBS iteration: 474 complete: 50.2760519981 seconds
# NBS iteration: 475 complete: 50.6405727863 seconds
# NBS iteration: 476 complete: 50.5946660042 seconds
# NBS iteration: 477 complete: 51.551145792 seconds
# NBS iteration: 478 complete: 52.3836867809 seconds
# NBS iteration: 479 complete: 55.1866779327 seconds
# NBS iteration: 480 complete: 52.8690471649 seconds
# NBS iteration: 481 complete: 52.300839901 seconds
# NBS iteration: 482 complete: 52.1793179512 seconds
# NBS iteration: 483 complete: 53.4459569454 seconds
# NBS iteration: 484 complete: 53.6217141151 seconds
# NBS iteration: 485 complete: 52.9351170063 seconds
# NBS iteration: 486 complete: 51.9178819656 seconds
# NBS iteration: 487 complete: 51.3135559559 seconds
# NBS iteration: 488 complete: 51.5572841167 seconds
# NBS iteration: 489 complete: 52.4106779099 seconds
# NBS iteration: 490 complete: 52.7653539181 seconds
# NBS iteration: 491 complete: 52.1351029873 seconds
# NBS iteration: 492 complete: 52.9741780758 seconds
# NBS iteration: 493 complete: 52.9166390896 seconds
# NBS iteration: 494 complete: 53.0487909317 seconds
# NBS iteration: 495 complete: 53.7640931606 seconds
# NBS iteration: 496 complete: 54.0730400085 seconds
# NBS iteration: 497 complete: 53.7754609585 seconds
# NBS iteration: 498 complete: 54.8046069145 seconds
# NBS iteration: 499 complete: 55.2110660076 seconds
# NBS iteration: 500 complete: 55.2455780506 seconds
# NBS iteration: 501 complete: 56.4598429203 seconds
# NBS iteration: 502 complete: 55.1063480377 seconds
# NBS iteration: 503 complete: 54.8468739986 seconds
# NBS iteration: 504 complete: 54.4291520119 seconds
# NBS iteration: 505 complete: 54.5991659164 seconds
# NBS iteration: 506 complete: 54.8349001408 seconds
# NBS iteration: 507 complete: 56.4057109356 seconds
# NBS iteration: 508 complete: 55.1271328926 seconds
# NBS iteration: 509 complete: 55.6044619083 seconds
# NBS iteration: 510 complete: 55.9169151783 seconds
# NBS iteration: 511 complete: 56.5349509716 seconds
# NBS iteration: 512 complete: 56.6578969955 seconds
# NBS iteration: 513 complete: 55.4854440689 seconds
# NBS iteration: 514 complete: 54.4882199764 seconds
# NBS iteration: 515 complete: 53.7460019588 seconds
# NBS iteration: 516 complete: 54.237653017 seconds
# NBS iteration: 517 complete: 54.184016943 seconds
# NBS iteration: 518 complete: 54.1349937916 seconds
# NBS iteration: 519 complete: 55.7969110012 seconds
# NBS iteration: 520 complete: 53.5071840286 seconds
# NBS iteration: 521 complete: 54.031566143 seconds
# NBS iteration: 522 complete: 54.4081039429 seconds
# NBS iteration: 523 complete: 54.7600879669 seconds
# NBS iteration: 524 complete: 54.3699359894 seconds
# NBS iteration: 525 complete: 55.4785130024 seconds
# NBS iteration: 526 complete: 55.1285150051 seconds
# NBS iteration: 527 complete: 55.7321829796 seconds
# NBS iteration: 528 complete: 55.1370551586 seconds
# NBS iteration: 529 complete: 55.1323518753 seconds
# NBS iteration: 530 complete: 54.7120680809 seconds
# NBS iteration: 531 complete: 50.6316380501 seconds
# NBS iteration: 532 complete: 49.2835440636 seconds
# NBS iteration: 533 complete: 47.8047730923 seconds
# NBS iteration: 534 complete: 49.252464056 seconds
# NBS iteration: 535 complete: 48.7964470387 seconds
# NBS iteration: 536 complete: 48.1079671383 seconds
# NBS iteration: 537 complete: 49.1255469322 seconds
# NBS iteration: 538 complete: 48.7629179955 seconds
# NBS iteration: 539 complete: 48.6802051067 seconds
# NBS iteration: 540 complete: 48.585340023 seconds
# NBS iteration: 541 complete: 49.2060160637 seconds
# NBS iteration: 542 complete: 48.9777479172 seconds
# NBS iteration: 543 complete: 48.8471531868 seconds
# NBS iteration: 544 complete: 49.5165941715 seconds
# NBS iteration: 545 complete: 49.9226341248 seconds
# NBS iteration: 546 complete: 49.4667971134 seconds
# NBS iteration: 547 complete: 49.7665970325 seconds
# NBS iteration: 548 complete: 49.6031880379 seconds
# NBS iteration: 549 complete: 50.5574178696 seconds
# NBS iteration: 550 complete: 50.314620018 seconds
# NBS iteration: 551 complete: 49.6557109356 seconds
# NBS iteration: 552 complete: 49.4368169308 seconds
# NBS iteration: 553 complete: 49.9129741192 seconds
# NBS iteration: 554 complete: 51.1464641094 seconds
# NBS iteration: 555 complete: 50.3127670288 seconds
# NBS iteration: 556 complete: 49.4098320007 seconds
# NBS iteration: 557 complete: 50.4605240822 seconds
# NBS iteration: 558 complete: 50.2364370823 seconds
# NBS iteration: 559 complete: 50.0447061062 seconds
# NBS iteration: 560 complete: 49.3875391483 seconds
# NBS iteration: 561 complete: 50.1435618401 seconds
# NBS iteration: 562 complete: 50.9508328438 seconds
# NBS iteration: 563 complete: 51.0034980774 seconds
# NBS iteration: 564 complete: 51.0191340446 seconds
# NBS iteration: 565 complete: 50.9132211208 seconds
# NBS iteration: 566 complete: 50.6087210178 seconds
# NBS iteration: 567 complete: 50.210875988 seconds
# NBS iteration: 568 complete: 50.557379961 seconds
# NBS iteration: 569 complete: 50.5703239441 seconds
# NBS iteration: 570 complete: 50.5794799328 seconds
# NBS iteration: 571 complete: 51.1696279049 seconds
# NBS iteration: 572 complete: 50.8747251034 seconds
# NBS iteration: 573 complete: 50.4336321354 seconds
# NBS iteration: 574 complete: 50.8778350353 seconds
# NBS iteration: 575 complete: 50.4987461567 seconds
# NBS iteration: 576 complete: 50.9791240692 seconds
# NBS iteration: 577 complete: 51.1205339432 seconds
# NBS iteration: 578 complete: 51.2576160431 seconds
# NBS iteration: 579 complete: 51.5138678551 seconds
# NBS iteration: 580 complete: 51.271089077 seconds
# NBS iteration: 581 complete: 51.6256668568 seconds
# NBS iteration: 582 complete: 51.301197052 seconds
# NBS iteration: 583 complete: 51.3572468758 seconds
# NBS iteration: 584 complete: 51.6829390526 seconds
# NBS iteration: 585 complete: 50.8675608635 seconds
# NBS iteration: 586 complete: 51.2040598392 seconds
# NBS iteration: 587 complete: 51.4047720432 seconds
# NBS iteration: 588 complete: 51.2979040146 seconds
# NBS iteration: 589 complete: 51.2412471771 seconds
# NBS iteration: 590 complete: 51.983479023 seconds
# NBS iteration: 591 complete: 51.4364230633 seconds
# NBS iteration: 592 complete: 51.5407619476 seconds
# NBS iteration: 593 complete: 51.5057718754 seconds
# NBS iteration: 594 complete: 51.4647099972 seconds
# NBS iteration: 595 complete: 51.9114120007 seconds
# NBS iteration: 596 complete: 52.1057109833 seconds
# NBS iteration: 597 complete: 51.5672280788 seconds
# NBS iteration: 598 complete: 51.6047751904 seconds
# NBS iteration: 599 complete: 51.9290390015 seconds
# NBS iteration: 600 complete: 51.2530620098 seconds
# NBS iteration: 601 complete: 51.3973069191 seconds
# NBS iteration: 602 complete: 51.8272540569 seconds
# NBS iteration: 603 complete: 51.3996200562 seconds
# NBS iteration: 604 complete: 51.2697920799 seconds
# NBS iteration: 605 complete: 51.6142349243 seconds
# NBS iteration: 606 complete: 51.5321309566 seconds
# NBS iteration: 607 complete: 51.3227419853 seconds
# NBS iteration: 608 complete: 51.4870281219 seconds
# NBS iteration: 609 complete: 51.6821658611 seconds
# NBS iteration: 610 complete: 51.9318521023 seconds
# NBS iteration: 611 complete: 51.2619700432 seconds
# NBS iteration: 612 complete: 51.3920178413 seconds
# NBS iteration: 613 complete: 51.8266010284 seconds
# NBS iteration: 614 complete: 51.4705059528 seconds
# NBS iteration: 615 complete: 50.8697140217 seconds
# NBS iteration: 616 complete: 51.2378139496 seconds
# NBS iteration: 617 complete: 51.840211153 seconds
# NBS iteration: 618 complete: 51.3326201439 seconds
# NBS iteration: 619 complete: 51.0059320927 seconds
# NBS iteration: 620 complete: 51.5675928593 seconds
# NBS iteration: 621 complete: 51.3669819832 seconds
# NBS iteration: 622 complete: 51.4836480618 seconds
# NBS iteration: 623 complete: 51.4226429462 seconds
# NBS iteration: 624 complete: 51.0257160664 seconds
# NBS iteration: 625 complete: 52.7954587936 seconds
# NBS iteration: 626 complete: 50.9511091709 seconds
# NBS iteration: 627 complete: 51.3099410534 seconds
# NBS iteration: 628 complete: 51.7388541698 seconds
# NBS iteration: 629 complete: 51.605096817 seconds
# NBS iteration: 630 complete: 51.4334979057 seconds
# NBS iteration: 631 complete: 51.6881198883 seconds
# NBS iteration: 632 complete: 51.3612580299 seconds
# NBS iteration: 633 complete: 51.4893109798 seconds
# NBS iteration: 634 complete: 51.3110280037 seconds
# NBS iteration: 635 complete: 50.6454560757 seconds
# NBS iteration: 636 complete: 51.0300650597 seconds
# NBS iteration: 637 complete: 51.7553241253 seconds
# NBS iteration: 638 complete: 51.2973339558 seconds
# NBS iteration: 639 complete: 51.1277561188 seconds
# NBS iteration: 640 complete: 51.5600409508 seconds
# NBS iteration: 641 complete: 52.0360889435 seconds
# NBS iteration: 642 complete: 51.5584070683 seconds
# NBS iteration: 643 complete: 51.4143710136 seconds
# NBS iteration: 644 complete: 51.3375349045 seconds
# NBS iteration: 645 complete: 50.7933170795 seconds
# NBS iteration: 646 complete: 51.5233900547 seconds
# NBS iteration: 647 complete: 51.5562980175 seconds
# NBS iteration: 648 complete: 50.9595768452 seconds
# NBS iteration: 649 complete: 50.8072221279 seconds
# NBS iteration: 650 complete: 51.6701991558 seconds
# NBS iteration: 651 complete: 50.9724559784 seconds
# NBS iteration: 652 complete: 51.474406004 seconds
# NBS iteration: 653 complete: 51.3690931797 seconds
# NBS iteration: 654 complete: 51.3718278408 seconds
# NBS iteration: 655 complete: 51.5226728916 seconds
# NBS iteration: 656 complete: 51.5753672123 seconds
# NBS iteration: 657 complete: 51.5654931068 seconds
# NBS iteration: 658 complete: 51.114221096 seconds
# NBS iteration: 659 complete: 51.4618480206 seconds
# NBS iteration: 660 complete: 51.9056830406 seconds
# NBS iteration: 661 complete: 51.3954639435 seconds
# NBS iteration: 662 complete: 51.137485981 seconds
# NBS iteration: 663 complete: 51.7239928246 seconds
# NBS iteration: 664 complete: 51.597080946 seconds
# NBS iteration: 665 complete: 51.360629797 seconds
# NBS iteration: 666 complete: 51.4463729858 seconds
# NBS iteration: 667 complete: 50.9850609303 seconds
# NBS iteration: 668 complete: 53.0216281414 seconds
# NBS iteration: 669 complete: 50.9787108898 seconds
# NBS iteration: 670 complete: 51.2622110844 seconds
# NBS iteration: 671 complete: 51.6411559582 seconds
# NBS iteration: 672 complete: 51.4908897877 seconds
# NBS iteration: 673 complete: 51.3572099209 seconds
# NBS iteration: 674 complete: 51.5782821178 seconds
# NBS iteration: 675 complete: 51.8337008953 seconds
# NBS iteration: 676 complete: 51.0602769852 seconds
# NBS iteration: 677 complete: 51.6219918728 seconds
# NBS iteration: 678 complete: 52.5249958038 seconds
# NBS iteration: 679 complete: 51.1529638767 seconds
# NBS iteration: 680 complete: 52.9440939426 seconds
# NBS iteration: 681 complete: 51.9804909229 seconds
# NBS iteration: 682 complete: 52.143914938 seconds
# NBS iteration: 683 complete: 50.9583089352 seconds
# NBS iteration: 684 complete: 51.7324829102 seconds
# NBS iteration: 685 complete: 51.5949888229 seconds
# NBS iteration: 686 complete: 50.9401788712 seconds
# NBS iteration: 687 complete: 51.6130049229 seconds
# NBS iteration: 688 complete: 52.3462359905 seconds
# NBS iteration: 689 complete: 51.302875042 seconds
# NBS iteration: 690 complete: 51.6982758045 seconds
# NBS iteration: 691 complete: 52.3394639492 seconds
# NBS iteration: 692 complete: 51.7823870182 seconds
# NBS iteration: 693 complete: 51.3978610039 seconds
# NBS iteration: 694 complete: 53.0914301872 seconds
# NBS iteration: 695 complete: 52.2538361549 seconds
# NBS iteration: 696 complete: 51.6454129219 seconds
# NBS iteration: 697 complete: 51.5290927887 seconds
# NBS iteration: 698 complete: 51.5004601479 seconds
# NBS iteration: 699 complete: 51.4109070301 seconds
# NBS iteration: 700 complete: 51.8880348206 seconds
# NBS iteration: 701 complete: 51.5351319313 seconds
# NBS iteration: 702 complete: 50.9336030483 seconds
# NBS iteration: 703 complete: 51.8143320084 seconds
# NBS iteration: 704 complete: 51.6560759544 seconds
# NBS iteration: 705 complete: 51.7817029953 seconds
# NBS iteration: 706 complete: 51.4789750576 seconds
# NBS iteration: 707 complete: 51.6918871403 seconds
# NBS iteration: 708 complete: 51.7218341827 seconds
# NBS iteration: 709 complete: 51.5816299915 seconds
# NBS iteration: 710 complete: 52.0740790367 seconds
# NBS iteration: 711 complete: 51.6943609715 seconds
# NBS iteration: 712 complete: 51.7704818249 seconds
# NBS iteration: 713 complete: 52.1360919476 seconds
# NBS iteration: 714 complete: 51.1197149754 seconds
# NBS iteration: 715 complete: 51.3949661255 seconds
# NBS iteration: 716 complete: 51.4409198761 seconds
# NBS iteration: 717 complete: 51.7802760601 seconds
# NBS iteration: 718 complete: 51.5297698975 seconds
# NBS iteration: 719 complete: 51.7827510834 seconds
# NBS iteration: 720 complete: 51.1226189137 seconds
# NBS iteration: 721 complete: 51.2391400337 seconds
# NBS iteration: 722 complete: 52.4834549427 seconds
# NBS iteration: 723 complete: 51.8643360138 seconds
# NBS iteration: 724 complete: 51.7227470875 seconds
# NBS iteration: 725 complete: 52.0074870586 seconds
# NBS iteration: 726 complete: 52.4829411507 seconds
# NBS iteration: 727 complete: 52.0659630299 seconds
# NBS iteration: 728 complete: 52.1864740849 seconds
# NBS iteration: 729 complete: 53.478705883 seconds
# NBS iteration: 730 complete: 51.5218758583 seconds
# NBS iteration: 731 complete: 51.2456099987 seconds
# NBS iteration: 732 complete: 50.8908140659 seconds
# NBS iteration: 733 complete: 50.6751151085 seconds
# NBS iteration: 734 complete: 51.0955290794 seconds
# NBS iteration: 735 complete: 51.6693189144 seconds
# NBS iteration: 736 complete: 54.8141260147 seconds
# NBS iteration: 737 complete: 51.6353189945 seconds
# NBS iteration: 738 complete: 51.7653989792 seconds
# NBS iteration: 739 complete: 51.3778858185 seconds
# NBS iteration: 740 complete: 51.379117012 seconds
# NBS iteration: 741 complete: 51.5136051178 seconds
# NBS iteration: 742 complete: 51.6297290325 seconds
# NBS iteration: 743 complete: 51.9191679955 seconds
# NBS iteration: 744 complete: 51.3726899624 seconds
# NBS iteration: 745 complete: 51.357583046 seconds
# NBS iteration: 746 complete: 51.3551688194 seconds
# NBS iteration: 747 complete: 51.7390930653 seconds
# NBS iteration: 748 complete: 51.3724579811 seconds
# NBS iteration: 749 complete: 51.0046520233 seconds
# NBS iteration: 750 complete: 51.3572289944 seconds
# NBS iteration: 751 complete: 51.7729620934 seconds
# NBS iteration: 752 complete: 51.3210158348 seconds
# NBS iteration: 753 complete: 51.4586789608 seconds
# NBS iteration: 754 complete: 51.5652439594 seconds
# NBS iteration: 755 complete: 52.0970511436 seconds
# NBS iteration: 756 complete: 51.6778979301 seconds
# NBS iteration: 757 complete: 51.4038379192 seconds
# NBS iteration: 758 complete: 51.6078369617 seconds
# NBS iteration: 759 complete: 50.8641479015 seconds
# NBS iteration: 760 complete: 51.5554950237 seconds
# NBS iteration: 761 complete: 51.5493240356 seconds
# NBS iteration: 762 complete: 51.0321171284 seconds
# NBS iteration: 763 complete: 51.4502131939 seconds
# NBS iteration: 764 complete: 52.6597390175 seconds
# NBS iteration: 765 complete: 51.435202837 seconds
# NBS iteration: 766 complete: 51.1533408165 seconds
# NBS iteration: 767 complete: 51.2531559467 seconds
# NBS iteration: 768 complete: 50.9536440372 seconds
# NBS iteration: 769 complete: 52.3037409782 seconds
# NBS iteration: 770 complete: 51.3674228191 seconds
# NBS iteration: 771 complete: 51.6193399429 seconds
# NBS iteration: 772 complete: 51.4339821339 seconds
# NBS iteration: 773 complete: 52.7435359955 seconds
# NBS iteration: 774 complete: 53.4697170258 seconds
# NBS iteration: 775 complete: 53.9044351578 seconds
# NBS iteration: 776 complete: 55.0806100368 seconds
# NBS iteration: 777 complete: 53.5273618698 seconds
# NBS iteration: 778 complete: 52.4262440205 seconds
# NBS iteration: 779 complete: 51.9601659775 seconds
# NBS iteration: 780 complete: 52.8532559872 seconds
# NBS iteration: 781 complete: 52.6830809116 seconds
# NBS iteration: 782 complete: 52.7248620987 seconds
# NBS iteration: 783 complete: 52.7784581184 seconds
# NBS iteration: 784 complete: 55.859153986 seconds
# NBS iteration: 785 complete: 54.6875350475 seconds
# NBS iteration: 786 complete: 54.7033948898 seconds
# NBS iteration: 787 complete: 54.2989759445 seconds
# NBS iteration: 788 complete: 54.4712159634 seconds
# NBS iteration: 789 complete: 53.9471790791 seconds
# NBS iteration: 790 complete: 52.7713801861 seconds
# NBS iteration: 791 complete: 54.171241045 seconds
# NBS iteration: 792 complete: 53.251830101 seconds
# NBS iteration: 793 complete: 53.456099987 seconds
# NBS iteration: 794 complete: 55.389966011 seconds
# NBS iteration: 795 complete: 53.0563390255 seconds
# NBS iteration: 796 complete: 53.0142149925 seconds
# NBS iteration: 797 complete: 53.1818301678 seconds
# NBS iteration: 798 complete: 54.4918310642 seconds
# NBS iteration: 799 complete: 54.3502430916 seconds
# NBS iteration: 800 complete: 54.5289258957 seconds
# NBS iteration: 801 complete: 53.7526218891 seconds
# NBS iteration: 802 complete: 54.1255471706 seconds
# NBS iteration: 803 complete: 55.1003508568 seconds
# NBS iteration: 804 complete: 52.6628279686 seconds
# NBS iteration: 805 complete: 54.2849349976 seconds
# NBS iteration: 806 complete: 54.0048191547 seconds
# NBS iteration: 807 complete: 53.1658260822 seconds
# NBS iteration: 808 complete: 53.4974040985 seconds
# NBS iteration: 809 complete: 53.2605080605 seconds
# NBS iteration: 810 complete: 53.1816580296 seconds
# NBS iteration: 811 complete: 53.7595689297 seconds
# NBS iteration: 812 complete: 52.8580269814 seconds
# NBS iteration: 813 complete: 53.7343380451 seconds
# NBS iteration: 814 complete: 52.5143039227 seconds
# NBS iteration: 815 complete: 53.2144141197 seconds
# NBS iteration: 816 complete: 53.3380310535 seconds
# NBS iteration: 817 complete: 53.6644999981 seconds
# NBS iteration: 818 complete: 53.6474928856 seconds
# NBS iteration: 819 complete: 53.0478961468 seconds
# NBS iteration: 820 complete: 53.2653479576 seconds
# NBS iteration: 821 complete: 53.1446528435 seconds
# NBS iteration: 822 complete: 53.0958340168 seconds
# NBS iteration: 823 complete: 52.9944550991 seconds
# NBS iteration: 824 complete: 52.210960865 seconds
# NBS iteration: 825 complete: 53.0235629082 seconds
# NBS iteration: 826 complete: 53.1945149899 seconds
# NBS iteration: 827 complete: 53.1767549515 seconds
# NBS iteration: 828 complete: 53.1127719879 seconds
# NBS iteration: 829 complete: 52.9395768642 seconds
# NBS iteration: 830 complete: 53.1575331688 seconds
# NBS iteration: 831 complete: 52.548664093 seconds
# NBS iteration: 832 complete: 54.0606789589 seconds
# NBS iteration: 833 complete: 52.944660902 seconds
# NBS iteration: 834 complete: 52.5339281559 seconds
# NBS iteration: 835 complete: 52.5808827877 seconds
# NBS iteration: 836 complete: 52.3605930805 seconds
# NBS iteration: 837 complete: 52.6644160748 seconds
# NBS iteration: 838 complete: 52.6219701767 seconds
# NBS iteration: 839 complete: 52.5150229931 seconds
# NBS iteration: 840 complete: 52.8796920776 seconds
# NBS iteration: 841 complete: 52.5742559433 seconds
# NBS iteration: 842 complete: 52.176459074 seconds
# NBS iteration: 843 complete: 52.3108980656 seconds
# NBS iteration: 844 complete: 52.3380599022 seconds
# NBS iteration: 845 complete: 52.6796710491 seconds
# NBS iteration: 846 complete: 52.8452260494 seconds
# NBS iteration: 847 complete: 52.6951918602 seconds
# NBS iteration: 848 complete: 52.7252421379 seconds
# NBS iteration: 849 complete: 52.8576109409 seconds
# NBS iteration: 850 complete: 52.8220801353 seconds
# NBS iteration: 851 complete: 52.3336310387 seconds
# NBS iteration: 852 complete: 52.2879889011 seconds
# NBS iteration: 853 complete: 52.3557171822 seconds
# NBS iteration: 854 complete: 52.6700849533 seconds
# NBS iteration: 855 complete: 52.0623009205 seconds
# NBS iteration: 856 complete: 52.2931880951 seconds
# NBS iteration: 857 complete: 53.2933630943 seconds
# NBS iteration: 858 complete: 52.0806441307 seconds
# NBS iteration: 859 complete: 51.8596279621 seconds
# NBS iteration: 860 complete: 53.1412808895 seconds
# NBS iteration: 861 complete: 52.5078859329 seconds
# NBS iteration: 862 complete: 52.5181539059 seconds
# NBS iteration: 863 complete: 52.3461880684 seconds
# NBS iteration: 864 complete: 52.1814000607 seconds
# NBS iteration: 865 complete: 52.7091209888 seconds
# NBS iteration: 866 complete: 54.1588978767 seconds
# NBS iteration: 867 complete: 52.1653280258 seconds
# NBS iteration: 868 complete: 53.1999151707 seconds
# NBS iteration: 869 complete: 53.3002820015 seconds
# NBS iteration: 870 complete: 53.016089201 seconds
# NBS iteration: 871 complete: 52.6400899887 seconds
# NBS iteration: 872 complete: 52.5197060108 seconds
# NBS iteration: 873 complete: 52.507174015 seconds
# NBS iteration: 874 complete: 52.7265331745 seconds
# NBS iteration: 875 complete: 52.9225010872 seconds
# NBS iteration: 876 complete: 53.9602720737 seconds
# NBS iteration: 877 complete: 52.7563169003 seconds
# NBS iteration: 878 complete: 54.065623045 seconds
# NBS iteration: 879 complete: 52.6808991432 seconds
# NBS iteration: 880 complete: 52.7216830254 seconds
# NBS iteration: 881 complete: 53.0977659225 seconds
# NBS iteration: 882 complete: 52.9871020317 seconds
# NBS iteration: 883 complete: 53.2456820011 seconds
# NBS iteration: 884 complete: 53.3845720291 seconds
# NBS iteration: 885 complete: 53.7210249901 seconds
# NBS iteration: 886 complete: 53.2455041409 seconds
# NBS iteration: 887 complete: 53.5354850292 seconds
# NBS iteration: 888 complete: 53.7620620728 seconds
# NBS iteration: 889 complete: 53.1765639782 seconds
# NBS iteration: 890 complete: 53.7079269886 seconds
# NBS iteration: 891 complete: 53.2175540924 seconds
# NBS iteration: 892 complete: 53.7100789547 seconds
# NBS iteration: 893 complete: 53.5579321384 seconds
# NBS iteration: 894 complete: 52.7974491119 seconds
# NBS iteration: 895 complete: 52.8588080406 seconds
# NBS iteration: 896 complete: 53.7297492027 seconds
# NBS iteration: 897 complete: 53.3255448341 seconds
# NBS iteration: 898 complete: 53.6709220409 seconds
# NBS iteration: 899 complete: 53.5671977997 seconds
# NBS iteration: 900 complete: 55.1782209873 seconds
# NBS iteration: 901 complete: 53.5531830788 seconds
# NBS iteration: 902 complete: 53.5010459423 seconds
# NBS iteration: 903 complete: 53.6844110489 seconds
# NBS iteration: 904 complete: 53.5805571079 seconds
# NBS iteration: 905 complete: 54.6548829079 seconds
# NBS iteration: 906 complete: 57.7208819389 seconds
# NBS iteration: 907 complete: 56.5383358002 seconds
# NBS iteration: 908 complete: 56.2347168922 seconds
# NBS iteration: 909 complete: 58.376912117 seconds
# NBS iteration: 910 complete: 56.0778241158 seconds
# NBS iteration: 911 complete: 53.9258129597 seconds
# NBS iteration: 912 complete: 54.9034688473 seconds
# NBS iteration: 913 complete: 54.5335400105 seconds
# NBS iteration: 914 complete: 54.1806719303 seconds
# NBS iteration: 915 complete: 54.7923719883 seconds
# NBS iteration: 916 complete: 54.7293729782 seconds
# NBS iteration: 917 complete: 53.1828980446 seconds
# NBS iteration: 918 complete: 55.0479559898 seconds
# NBS iteration: 919 complete: 56.3558590412 seconds
# NBS iteration: 920 complete: 55.5462899208 seconds
# NBS iteration: 921 complete: 53.4102940559 seconds
# NBS iteration: 922 complete: 53.6205420494 seconds
# NBS iteration: 923 complete: 54.1679179668 seconds
# NBS iteration: 924 complete: 53.6766250134 seconds
# NBS iteration: 925 complete: 53.6546900272 seconds
# NBS iteration: 926 complete: 53.3408310413 seconds
# NBS iteration: 927 complete: 53.4666349888 seconds
# NBS iteration: 928 complete: 55.0583159924 seconds
# NBS iteration: 929 complete: 54.71773386 seconds
# NBS iteration: 930 complete: 53.6754980087 seconds
# NBS iteration: 931 complete: 53.4500639439 seconds
# NBS iteration: 932 complete: 54.0018870831 seconds
# NBS iteration: 933 complete: 55.4933941364 seconds
# NBS iteration: 934 complete: 53.3409318924 seconds
# NBS iteration: 935 complete: 53.9954478741 seconds
# NBS iteration: 936 complete: 54.239178896 seconds
# NBS iteration: 937 complete: 54.2618470192 seconds
# NBS iteration: 938 complete: 53.7826421261 seconds
# NBS iteration: 939 complete: 53.5629839897 seconds
# NBS iteration: 940 complete: 56.3865418434 seconds
# NBS iteration: 941 complete: 55.0777659416 seconds
# NBS iteration: 942 complete: 54.4808850288 seconds
# NBS iteration: 943 complete: 54.8164138794 seconds
# NBS iteration: 944 complete: 56.2350871563 seconds
# NBS iteration: 945 complete: 54.7386519909 seconds
# NBS iteration: 946 complete: 54.5383059978 seconds
# NBS iteration: 947 complete: 54.7803099155 seconds
# NBS iteration: 948 complete: 54.862637043 seconds
# NBS iteration: 949 complete: 54.436563015 seconds
# NBS iteration: 950 complete: 54.9993770123 seconds
# NBS iteration: 951 complete: 55.8412530422 seconds
# NBS iteration: 952 complete: 54.6670298576 seconds
# NBS iteration: 953 complete: 54.2604439259 seconds
# NBS iteration: 954 complete: 54.6857891083 seconds
# NBS iteration: 955 complete: 54.6511070728 seconds
# NBS iteration: 956 complete: 55.0112030506 seconds
# NBS iteration: 957 complete: 54.6776399612 seconds
# NBS iteration: 958 complete: 54.6343870163 seconds
# NBS iteration: 959 complete: 53.7042851448 seconds
# NBS iteration: 960 complete: 54.2482759953 seconds
# NBS iteration: 961 complete: 54.9847910404 seconds
# NBS iteration: 962 complete: 54.5402598381 seconds
# NBS iteration: 963 complete: 54.8255529404 seconds
# NBS iteration: 964 complete: 55.3441300392 seconds
# NBS iteration: 965 complete: 54.6643240452 seconds
# NBS iteration: 966 complete: 56.1007928848 seconds
# NBS iteration: 967 complete: 54.4879519939 seconds
# NBS iteration: 968 complete: 54.2146170139 seconds
# NBS iteration: 969 complete: 54.4518668652 seconds
# NBS iteration: 970 complete: 54.3722999096 seconds
# NBS iteration: 971 complete: 54.9916079044 seconds
# NBS iteration: 972 complete: 54.9469668865 seconds
# NBS iteration: 973 complete: 54.8519740105 seconds
# NBS iteration: 974 complete: 56.2335989475 seconds
# NBS iteration: 975 complete: 54.8246951103 seconds
# NBS iteration: 976 complete: 54.8379878998 seconds
# NBS iteration: 977 complete: 55.6776850224 seconds
# NBS iteration: 978 complete: 54.7063779831 seconds
# NBS iteration: 979 complete: 54.1440689564 seconds
# NBS iteration: 980 complete: 53.8651068211 seconds
# NBS iteration: 981 complete: 54.7299351692 seconds
# NBS iteration: 982 complete: 54.8430919647 seconds
# NBS iteration: 983 complete: 54.6994080544 seconds
# NBS iteration: 984 complete: 54.7917189598 seconds
# NBS iteration: 985 complete: 53.9652950764 seconds
# NBS iteration: 986 complete: 54.5261690617 seconds
# NBS iteration: 987 complete: 55.0737829208 seconds
# NBS iteration: 988 complete: 55.4686717987 seconds
# NBS iteration: 989 complete: 54.9469451904 seconds
# NBS iteration: 990 complete: 55.1320061684 seconds
# NBS iteration: 991 complete: 54.9716761112 seconds
# NBS iteration: 992 complete: 54.215939045 seconds
# NBS iteration: 993 complete: 54.7765159607 seconds
# NBS iteration: 994 complete: 54.9506499767 seconds
# NBS iteration: 995 complete: 54.4220080376 seconds
# NBS iteration: 996 complete: 54.7062630653 seconds
# NBS iteration: 997 complete: 54.5890991688 seconds
# NBS iteration: 998 complete: 54.3382852077 seconds
# NBS iteration: 999 complete: 54.6228249073 seconds
# NBS iteration: 1000 complete: 54.4893329144 seconds

# %% [markdown]
# ## Consensus Clustering

# %% [markdown]
# > __Steps for consensus clustering__
# 1. Takes a list of 'H' (patient-by-k) dataframes and performs 'hard' consensus clustering
# 2. Using hierarchical clustering and average linkage
# 3. Returns similarity table (distance is 1-similarity) and linkage map of patients
# 4. Also returns cluster assignment map of patients if wanted

# %%
if run_pyNBS_params['consensus_cluster']:
    NBS_cc_table, NBS_cc_linkage, NBS_cluster_assign = cc.consensus_hclust_hard(Hlist, NBS_options['netNMF_k'], assign_cluster=run_pyNBS_params['assign_clusters'])
    if run_pyNBS_params['verbose']:
        print 'Consensus Clustering complete'
    if run_pyNBS_params['save_co_cluster_matrix'] is not None:
        NBS_cc_table.to_csv(run_pyNBS_params['save_co_cluster_matrix'])
        if run_pyNBS_params['verbose']:
            print 'Co-clustering matrix saved'
    if run_pyNBS_params['save_cluster_assignments'] is not None:
        NBS_cluster_assign.to_csv(run_pyNBS_params['save_cluster_assignments'])
        if run_pyNBS_params['verbose']:
            print 'Cluster assignments saved'
# Out:
# Consensus Clustering complete
# Co-clustering matrix saved
# Cluster assignments saved

# %%
#Cluster assignments

# Please make sure you modify file path for loading/saving to indicate your local directory
ori_assin_table = pd.read_table('/cellar/users/t1jia/pyNBS/Hofree_NBS_paper_results/Paper_OV_NBS_Results.csv',sep=',',index_col=0)

cluster_assign = pd.concat([ori_assin_table.iloc[:,0], NBS_cluster_assign], axis=1).dropna(axis=0,how='any').astype(int)
ori_paper_cluster_assign = cluster_assign.iloc[:,0]
NBS_cluster_assign = cluster_assign.iloc[:,1].astype(int)

# %%
# Plot Consensus Cluster Map
if run_pyNBS_params['plot_co_cluster_map']:
    NBS_cluster_assign_cmap = plot.cluster_color_assign(NBS_cluster_assign, name='pyNBS Cluster Assignment')
    ori_paper_cluster_assign_cmap = plot.cluster_color_assign(ori_paper_cluster_assign, name='Original Paper Cluster Assignment')
    plot.plot_cc_map(NBS_cc_table, NBS_cc_linkage, title=run_pyNBS_params['plot_title'], row_color_map=ori_paper_cluster_assign_cmap, 
                     col_color_map=NBS_cluster_assign_cmap, save_path=run_pyNBS_params['save_co_cluster_map'])
    if run_pyNBS_params['verbose']:
        print 'Consensus Clustering map saved'
# Out:
# /cellar/users/t1jia/anaconda2/lib/python2.7/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Consensus Clustering map saved

# %%
Image(filename = run_pyNBS_params['save_co_cluster_map'], width=600, height=600)

# %% [markdown]
# ## Result Compare to the Orignal Paper

# %% [markdown]
# __Adjusted Rand Index (ARI)__
# > Rand index adjusted for chance.
# $$ARI = \frac{RI - \mathbb{E}(RI)}{ \max(RI) - \mathbb{E}(RI)}$$
#
# __Adjusted Mutual Info Score (AMI)__
# > Adjusted Mutual Information between two clusterings.
# $${AMI(U, V) = \frac{MI(U, V) - \mathbb{E}(MI(U, V))}{\max(H(U), H(V)) - \mathbb{E}(MI(U, V))}}$$
#
# __Kaplan-Meier Plot__
# > Kaplan-Meier estimate is defined as:$$\hat{S}(t) = \prod_{t_i \lt t} \frac{n_i - d_i}{n_i}$$
# where $d_i$ are the number of death events at time $t$ and $n_i$ is the number of subjects at risk of death just prior to time $t$.

# %%
adj_rand_index = adjusted_rand_score(ori_paper_cluster_assign,NBS_cluster_assign)
adj_mutual_info_score = adjusted_mutual_info_score(ori_paper_cluster_assign,NBS_cluster_assign)
if run_pyNBS_params['verbose']:
    print 'Adjusted Rand Index is: ' + str(adj_rand_index)
    print 'Adjusted Mutual Info Score is: ' + str(adj_mutual_info_score)
# Out:
# Adjusted Rand Index is: 0.857994033778
# Adjusted Mutual Info Score is: 0.762186639944

# %%
# Please make sure you modify file path for loading/saving to indicate your local directory
clin_path = '/cellar/users/t1jia/pyNBS/data/OV.clin.merged.picked.txt'

plot.cluster_KMplot(NBS_cluster_assign,clin_path,title='OV on HM90 pyNBS Survival Plot', save_path = run_pyNBS_params['save_km_plot'])
Image(filename = run_pyNBS_params['save_km_plot'], width=600, height=600)
# Out:
# Multi-Class Log-Rank P: 0.00447989441194
